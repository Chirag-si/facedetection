# %% [markdown]
# # Using Model for Real-Time Predicitions

# %%
import cv2
import tensorflow as tf
from tensorflow.keras.models import load_model
import numpy as np

# %%
facetracker = load_model('facetracker.keras')

# %%
while cap.isOpened():
    _, frame = cap.read()
    
    # Get frame dimensions
    frame_height, frame_width, _ = frame.shape
    
    # Convert frame to RGB and resize for the model
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    resized = tf.image.resize(rgb, (120, 120))
    normalized = resized / 255.0
    
    # Make predictions
    yhat = facetracker.predict(np.expand_dims(normalized, axis=0))
    sample_coords = yhat[1][0]  # Assuming the second output is bounding box coords
    
    # Debugging: Print predictions
    print(f"Confidence: {yhat[0]}, Bounding box (normalized): {sample_coords}")
    
    # Check detection confidence
    if yhat[0] > 0.5: 
        # Scale bounding box coordinates back to the original frame size
        bbox_start = tuple(np.multiply(sample_coords[:2], [frame_width, frame_height]).astype(int))
        bbox_end = tuple(np.multiply(sample_coords[2:], [frame_width, frame_height]).astype(int))
        
        # Debugging: Check scaled coordinates
        print(f"Bounding box (scaled): Top-left {bbox_start}, Bottom-right {bbox_end}")
        
        # Draw the bounding box
        cv2.rectangle(frame, bbox_start, bbox_end, (255, 0, 0), 2)
        
        # Draw label background
        label_bbox_start = (bbox_start[0], bbox_start[1] - 30)
        label_bbox_end = (bbox_start[0] + 80, bbox_start[1])
        cv2.rectangle(frame, label_bbox_start, label_bbox_end, (255, 0, 0), -1)
        
        # Draw the label text
        cv2.putText(frame, 'face', (bbox_start[0], bbox_start[1] - 5),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    
    # Show the frame
    cv2.imshow('EyeTrack', frame)
    
    # Break loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Confidence: [[0.999999]], Bounding box (normalized): [0.39363402 0.25828853 0.5364899  0.58165944]
# Bounding box (scaled): Top-left (np.int64(503), np.int64(185)), Bottom-right (np.int64(686), np.int64(418))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Confidence: [[0.9999994]], Bounding box (normalized): [0.40135014 0.23938356 0.5424409  0.56541425]
# Bounding box (scaled): Top-left (np.int64(513), np.int64(172)), Bottom-right (np.int64(694), np.int64(407))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Confidence: [[0.9999995]], Bounding box (normalized): [0.40388587 0.23183018 0.54451853 0.55899465]
# Bounding box (scaled): Top-left (np.int64(516), np.int64(166)), Bottom-right (np.int64(696), np.int64(402))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Confidence: [[0.9999996]], Bounding box (normalized): [0.40566793 0.23198406 0.5464945  0.5581625 ]
# Bounding box (scaled): Top-left (np.int64(519), np.int64(167)), Bottom-right (np.int64(699), np.int64(401))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Confidence: [[0.99999964]], Bounding box (normalized): [0.40473282 0.23026234 0.54516435 0.5571629 ]
# Bounding box (scaled): Top-left (np.int64(518), np.int64(165)), Bottom-right (np.int64(697), np.int64(401))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.9999996]], Bounding box (normalized): [0.40381843 0.23543917 0.544488   0.5609963 ]
# Bounding box (scaled): Top-left (np.int64(516), np.int64(169)), Bottom-right (np.int64(696), np.int64(403))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9999997]], Bounding box (normalized): [0.40672344 0.22881986 0.54722077 0.5563889 ]
# Bounding box (scaled): Top-left (np.int64(520), np.int64(164)), Bottom-right (np.int64(700), np.int64(400))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.9999996]], Bounding box (normalized): [0.40270072 0.23599471 0.54311466 0.5613566 ]
# Bounding box (scaled): Top-left (np.int64(515), np.int64(169)), Bottom-right (np.int64(695), np.int64(404))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Confidence: [[0.9999995]], Bounding box (normalized): [0.39974812 0.24179159 0.5407094  0.567336  ]
# Bounding box (scaled): Top-left (np.int64(511), np.int64(174)), Bottom-right (np.int64(692), np.int64(408))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.99999964]], Bounding box (normalized): [0.40283576 0.23699011 0.544538   0.56375027]
# Bounding box (scaled): Top-left (np.int64(515), np.int64(170)), Bottom-right (np.int64(697), np.int64(405))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Confidence: [[0.9999995]], Bounding box (normalized): [0.40041956 0.24399664 0.5418344  0.56713057]
# Bounding box (scaled): Top-left (np.int64(512), np.int64(175)), Bottom-right (np.int64(693), np.int64(408))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Confidence: [[0.99999946]], Bounding box (normalized): [0.39891028 0.2461177  0.5403493  0.56894964]
# Bounding box (scaled): Top-left (np.int64(510), np.int64(177)), Bottom-right (np.int64(691), np.int64(409))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Confidence: [[0.9999994]], Bounding box (normalized): [0.39554805 0.25176463 0.53713137 0.57482874]
# Bounding box (scaled): Top-left (np.int64(506), np.int64(181)), Bottom-right (np.int64(687), np.int64(413))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.99999934]], Bounding box (normalized): [0.39531937 0.25135827 0.53649294 0.5731662 ]
# Bounding box (scaled): Top-left (np.int64(506), np.int64(180)), Bottom-right (np.int64(686), np.int64(412))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.99999946]], Bounding box (normalized): [0.39773238 0.24659878 0.5391653  0.5706171 ]
# Bounding box (scaled): Top-left (np.int64(509), np.int64(177)), Bottom-right (np.int64(690), np.int64(410))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.9999996]], Bounding box (normalized): [0.3977815  0.24078953 0.53876406 0.5671788 ]
# Bounding box (scaled): Top-left (np.int64(509), np.int64(173)), Bottom-right (np.int64(689), np.int64(408))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9999996]], Bounding box (normalized): [0.3982927  0.24242008 0.53965926 0.56902283]
# Bounding box (scaled): Top-left (np.int64(509), np.int64(174)), Bottom-right (np.int64(690), np.int64(409))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.9999995]], Bounding box (normalized): [0.39712152 0.24500188 0.5380887  0.5696317 ]
# Bounding box (scaled): Top-left (np.int64(508), np.int64(176)), Bottom-right (np.int64(688), np.int64(410))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.9999995]], Bounding box (normalized): [0.39436364 0.24516112 0.5348159  0.5702349 ]
# Bounding box (scaled): Top-left (np.int64(504), np.int64(176)), Bottom-right (np.int64(684), np.int64(410))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.9999996]], Bounding box (normalized): [0.39556897 0.24339181 0.5366546  0.5700029 ]
# Bounding box (scaled): Top-left (np.int64(506), np.int64(175)), Bottom-right (np.int64(686), np.int64(410))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.9999993]], Bounding box (normalized): [0.39345133 0.2544098  0.53380984 0.5744301 ]
# Bounding box (scaled): Top-left (np.int64(503), np.int64(183)), Bottom-right (np.int64(683), np.int64(413))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.9999993]], Bounding box (normalized): [0.39534736 0.25013667 0.5348039  0.57016295]
# Bounding box (scaled): Top-left (np.int64(506), np.int64(180)), Bottom-right (np.int64(684), np.int64(410))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Confidence: [[0.9999995]], Bounding box (normalized): [0.39885837 0.24377503 0.54101264 0.5697647 ]
# Bounding box (scaled): Top-left (np.int64(510), np.int64(175)), Bottom-right (np.int64(692), np.int64(410))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9999992]], Bounding box (normalized): [0.39782205 0.25532362 0.5399289  0.57535505]
# Bounding box (scaled): Top-left (np.int64(509), np.int64(183)), Bottom-right (np.int64(691), np.int64(414))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.99999917]], Bounding box (normalized): [0.39780977 0.25704166 0.53924185 0.5748705 ]
# Bounding box (scaled): Top-left (np.int64(509), np.int64(185)), Bottom-right (np.int64(690), np.int64(413))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.9999992]], Bounding box (normalized): [0.39729014 0.25223333 0.5382737  0.5716077 ]
# Bounding box (scaled): Top-left (np.int64(508), np.int64(181)), Bottom-right (np.int64(688), np.int64(411))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9999994]], Bounding box (normalized): [0.40078446 0.24685447 0.541642   0.56727684]
# Bounding box (scaled): Top-left (np.int64(513), np.int64(177)), Bottom-right (np.int64(693), np.int64(408))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.99999934]], Bounding box (normalized): [0.3980921  0.25437516 0.53999984 0.5755067 ]
# Bounding box (scaled): Top-left (np.int64(509), np.int64(183)), Bottom-right (np.int64(691), np.int64(414))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9999994]], Bounding box (normalized): [0.4003084  0.24943902 0.5420076  0.570543  ]
# Bounding box (scaled): Top-left (np.int64(512), np.int64(179)), Bottom-right (np.int64(693), np.int64(410))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99999946]], Bounding box (normalized): [0.40148613 0.24926977 0.5440437  0.5720166 ]
# Bounding box (scaled): Top-left (np.int64(513), np.int64(179)), Bottom-right (np.int64(696), np.int64(411))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9999994]], Bounding box (normalized): [0.39987764 0.25066182 0.5423758  0.5724825 ]
# Bounding box (scaled): Top-left (np.int64(511), np.int64(180)), Bottom-right (np.int64(694), np.int64(412))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99999934]], Bounding box (normalized): [0.40098515 0.24938886 0.54275745 0.56904036]
# Bounding box (scaled): Top-left (np.int64(513), np.int64(179)), Bottom-right (np.int64(694), np.int64(409))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99999946]], Bounding box (normalized): [0.4027986  0.24249403 0.54384804 0.563642  ]
# Bounding box (scaled): Top-left (np.int64(515), np.int64(174)), Bottom-right (np.int64(696), np.int64(405))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99999946]], Bounding box (normalized): [0.4019766  0.24263988 0.5431141  0.564247  ]
# Bounding box (scaled): Top-left (np.int64(514), np.int64(174)), Bottom-right (np.int64(695), np.int64(406))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99999934]], Bounding box (normalized): [0.40018317 0.25008717 0.5415971  0.570502  ]
# Bounding box (scaled): Top-left (np.int64(512), np.int64(180)), Bottom-right (np.int64(693), np.int64(410))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9999995]], Bounding box (normalized): [0.40320012 0.2408724  0.5440109  0.5625266 ]
# Bounding box (scaled): Top-left (np.int64(516), np.int64(173)), Bottom-right (np.int64(696), np.int64(405))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99999946]], Bounding box (normalized): [0.39974555 0.2466739  0.5413161  0.5687549 ]
# Bounding box (scaled): Top-left (np.int64(511), np.int64(177)), Bottom-right (np.int64(692), np.int64(409))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.9999993]], Bounding box (normalized): [0.39440858 0.2569676  0.5363243  0.57751054]
# Bounding box (scaled): Top-left (np.int64(504), np.int64(185)), Bottom-right (np.int64(686), np.int64(415))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9999991]], Bounding box (normalized): [0.39459586 0.2603263  0.5359286  0.5786004 ]
# Bounding box (scaled): Top-left (np.int64(505), np.int64(187)), Bottom-right (np.int64(685), np.int64(416))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99999946]], Bounding box (normalized): [0.40250382 0.24228904 0.54292184 0.566077  ]
# Bounding box (scaled): Top-left (np.int64(515), np.int64(174)), Bottom-right (np.int64(694), np.int64(407))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.99999934]], Bounding box (normalized): [0.4024172  0.2490326  0.54284203 0.5688657 ]
# Bounding box (scaled): Top-left (np.int64(515), np.int64(179)), Bottom-right (np.int64(694), np.int64(409))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Confidence: [[0.99999934]], Bounding box (normalized): [0.40349895 0.25082645 0.5452395  0.5711507 ]
# Bounding box (scaled): Top-left (np.int64(516), np.int64(180)), Bottom-right (np.int64(697), np.int64(411))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Confidence: [[0.9999988]], Bounding box (normalized): [0.39116088 0.286594   0.5353632  0.60388577]
# Bounding box (scaled): Top-left (np.int64(500), np.int64(206)), Bottom-right (np.int64(685), np.int64(434))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99999833]], Bounding box (normalized): [0.3878744 0.3157076 0.5317545 0.6300479]
# Bounding box (scaled): Top-left (np.int64(496), np.int64(227)), Bottom-right (np.int64(680), np.int64(453))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.9999983]], Bounding box (normalized): [0.38532382 0.31775033 0.5289106  0.6319097 ]
# Bounding box (scaled): Top-left (np.int64(493), np.int64(228)), Bottom-right (np.int64(677), np.int64(454))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9999988]], Bounding box (normalized): [0.3892826 0.300588  0.5339669 0.6196906]
# Bounding box (scaled): Top-left (np.int64(498), np.int64(216)), Bottom-right (np.int64(683), np.int64(446))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.9999993]], Bounding box (normalized): [0.39615557 0.28496477 0.54243034 0.6060272 ]
# Bounding box (scaled): Top-left (np.int64(507), np.int64(205)), Bottom-right (np.int64(694), np.int64(436))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99999875]], Bounding box (normalized): [0.38817388 0.29546425 0.5329118  0.6134892 ]
# Bounding box (scaled): Top-left (np.int64(496), np.int64(212)), Bottom-right (np.int64(682), np.int64(441))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9999989]], Bounding box (normalized): [0.38899517 0.2870575  0.53362143 0.60516655]
# Bounding box (scaled): Top-left (np.int64(497), np.int64(206)), Bottom-right (np.int64(683), np.int64(435))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9999994]], Bounding box (normalized): [0.3917413  0.26619425 0.5360905  0.5921467 ]
# Bounding box (scaled): Top-left (np.int64(501), np.int64(191)), Bottom-right (np.int64(686), np.int64(426))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9999989]], Bounding box (normalized): [0.38646826 0.26971763 0.52813095 0.59102416]
# Bounding box (scaled): Top-left (np.int64(494), np.int64(194)), Bottom-right (np.int64(676), np.int64(425))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Confidence: [[0.9999989]], Bounding box (normalized): [0.38484114 0.25971338 0.52423835 0.5799033 ]
# Bounding box (scaled): Top-left (np.int64(492), np.int64(186)), Bottom-right (np.int64(671), np.int64(417))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Confidence: [[0.9999989]], Bounding box (normalized): [0.38456962 0.2554507  0.522879   0.5739342 ]
# Bounding box (scaled): Top-left (np.int64(492), np.int64(183)), Bottom-right (np.int64(669), np.int64(413))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9999994]], Bounding box (normalized): [0.3883019  0.24320817 0.526871   0.56807315]
# Bounding box (scaled): Top-left (np.int64(497), np.int64(175)), Bottom-right (np.int64(674), np.int64(409))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99999934]], Bounding box (normalized): [0.3828506  0.24868253 0.52192664 0.57532287]
# Bounding box (scaled): Top-left (np.int64(490), np.int64(179)), Bottom-right (np.int64(668), np.int64(414))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99999905]], Bounding box (normalized): [0.37866595 0.25245357 0.5171698  0.5737365 ]
# Bounding box (scaled): Top-left (np.int64(484), np.int64(181)), Bottom-right (np.int64(661), np.int64(413))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.99999934]], Bounding box (normalized): [0.38020384 0.23088087 0.516065   0.5558515 ]
# Bounding box (scaled): Top-left (np.int64(486), np.int64(166)), Bottom-right (np.int64(660), np.int64(400))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Confidence: [[0.99999905]], Bounding box (normalized): [0.37059268 0.2540249  0.508524   0.579552  ]
# Bounding box (scaled): Top-left (np.int64(474), np.int64(182)), Bottom-right (np.int64(650), np.int64(417))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99999934]], Bounding box (normalized): [0.36687967 0.24307661 0.5037602  0.5745499 ]
# Bounding box (scaled): Top-left (np.int64(469), np.int64(175)), Bottom-right (np.int64(644), np.int64(413))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.99999917]], Bounding box (normalized): [0.35979763 0.2456397  0.49714965 0.5776068 ]
# Bounding box (scaled): Top-left (np.int64(460), np.int64(176)), Bottom-right (np.int64(636), np.int64(415))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9999996]], Bounding box (normalized): [0.35706773 0.22394048 0.49480128 0.56551766]
# Bounding box (scaled): Top-left (np.int64(457), np.int64(161)), Bottom-right (np.int64(633), np.int64(407))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.9999996]], Bounding box (normalized): [0.3468687  0.21490435 0.48515695 0.56109923]
# Bounding box (scaled): Top-left (np.int64(443), np.int64(154)), Bottom-right (np.int64(621), np.int64(403))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Confidence: [[0.99999976]], Bounding box (normalized): [0.34025636 0.19709224 0.48212066 0.5579331 ]
# Bounding box (scaled): Top-left (np.int64(435), np.int64(141)), Bottom-right (np.int64(617), np.int64(401))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Confidence: [[0.99999976]], Bounding box (normalized): [0.33564574 0.19018526 0.47279325 0.5465143 ]
# Bounding box (scaled): Top-left (np.int64(429), np.int64(136)), Bottom-right (np.int64(605), np.int64(393))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Confidence: [[0.9999993]], Bounding box (normalized): [0.32982063 0.17764238 0.45412135 0.5112972 ]
# Bounding box (scaled): Top-left (np.int64(422), np.int64(127)), Bottom-right (np.int64(581), np.int64(368))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.99999315]], Bounding box (normalized): [0.3042124  0.18870483 0.41896883 0.49941868]
# Bounding box (scaled): Top-left (np.int64(389), np.int64(135)), Bottom-right (np.int64(536), np.int64(359))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.999977]], Bounding box (normalized): [0.27942297 0.1722353  0.39107788 0.48047632]
# Bounding box (scaled): Top-left (np.int64(357), np.int64(124)), Bottom-right (np.int64(500), np.int64(345))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Confidence: [[0.99980974]], Bounding box (normalized): [0.23041555 0.15691985 0.34520227 0.46037853]
# Bounding box (scaled): Top-left (np.int64(294), np.int64(112)), Bottom-right (np.int64(441), np.int64(331))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99910384]], Bounding box (normalized): [0.197339   0.11923457 0.30958912 0.3903171 ]
# Bounding box (scaled): Top-left (np.int64(252), np.int64(85)), Bottom-right (np.int64(396), np.int64(281))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99921894]], Bounding box (normalized): [0.16761972 0.10794456 0.2820793  0.39531475]
# Bounding box (scaled): Top-left (np.int64(214), np.int64(77)), Bottom-right (np.int64(361), np.int64(284))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.9605194]], Bounding box (normalized): [0.08851907 0.0740241  0.15664612 0.24394135]
# Bounding box (scaled): Top-left (np.int64(113), np.int64(53)), Bottom-right (np.int64(200), np.int64(175))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.06899009]], Bounding box (normalized): [0.03831473 0.02918858 0.05897081 0.07568632]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Confidence: [[0.00248935]], Bounding box (normalized): [0.01411777 0.00832154 0.0201569  0.02074862]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.00083434]], Bounding box (normalized): [0.00939517 0.0061186  0.01311389 0.01434739]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.00130495]], Bounding box (normalized): [0.00989579 0.00616546 0.0136479  0.01520676]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Confidence: [[0.0006679]], Bounding box (normalized): [0.00813896 0.00496627 0.01113562 0.01193925]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.00163506]], Bounding box (normalized): [0.01158464 0.00677525 0.01615231 0.01688722]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.01007776]], Bounding box (normalized): [0.021612   0.01290289 0.03185132 0.03363045]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.1307492]], Bounding box (normalized): [0.04330033 0.03191165 0.06853929 0.08762098]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.6522845]], Bounding box (normalized): [0.06715474 0.05074819 0.11425788 0.15407346]
# Bounding box (scaled): Top-left (np.int64(85), np.int64(36)), Bottom-right (np.int64(146), np.int64(110))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9047207]], Bounding box (normalized): [0.09811453 0.06501065 0.1608977  0.21048546]
# Bounding box (scaled): Top-left (np.int64(125), np.int64(46)), Bottom-right (np.int64(205), np.int64(151))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.94285333]], Bounding box (normalized): [0.14490144 0.08528565 0.21634813 0.25884405]
# Bounding box (scaled): Top-left (np.int64(185), np.int64(61)), Bottom-right (np.int64(276), np.int64(186))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9992231]], Bounding box (normalized): [0.25199458 0.1408929  0.34596702 0.391452  ]
# Bounding box (scaled): Top-left (np.int64(322), np.int64(101)), Bottom-right (np.int64(442), np.int64(281))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9999928]], Bounding box (normalized): [0.31125638 0.18248506 0.41878045 0.49814057]
# Bounding box (scaled): Top-left (np.int64(398), np.int64(131)), Bottom-right (np.int64(536), np.int64(358))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.99999887]], Bounding box (normalized): [0.2838944  0.28974622 0.4342407  0.6689442 ]
# Bounding box (scaled): Top-left (np.int64(363), np.int64(208)), Bottom-right (np.int64(555), np.int64(481))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99999976]], Bounding box (normalized): [0.2934318  0.30976146 0.4541618  0.69598216]
# Bounding box (scaled): Top-left (np.int64(375), np.int64(223)), Bottom-right (np.int64(581), np.int64(501))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9999997]], Bounding box (normalized): [0.31755525 0.26476896 0.46351483 0.61514443]
# Bounding box (scaled): Top-left (np.int64(406), np.int64(190)), Bottom-right (np.int64(593), np.int64(442))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[1.]], Bounding box (normalized): [0.339409   0.20368919 0.48768735 0.565488  ]
# Bounding box (scaled): Top-left (np.int64(434), np.int64(146)), Bottom-right (np.int64(624), np.int64(407))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[1.]], Bounding box (normalized): [0.3703825  0.18094948 0.5129828  0.52028555]
# Bounding box (scaled): Top-left (np.int64(474), np.int64(130)), Bottom-right (np.int64(656), np.int64(374))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[1.]], Bounding box (normalized): [0.38153917 0.14626794 0.53649473 0.51207954]
# Bounding box (scaled): Top-left (np.int64(488), np.int64(105)), Bottom-right (np.int64(686), np.int64(368))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[1.]], Bounding box (normalized): [0.39331886 0.14315268 0.548024   0.49742377]
# Bounding box (scaled): Top-left (np.int64(503), np.int64(103)), Bottom-right (np.int64(701), np.int64(358))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[1.]], Bounding box (normalized): [0.41286752 0.16184029 0.5732442  0.5143917 ]
# Bounding box (scaled): Top-left (np.int64(528), np.int64(116)), Bottom-right (np.int64(733), np.int64(370))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[1.]], Bounding box (normalized): [0.4276261  0.14750025 0.5866213  0.50565434]
# Bounding box (scaled): Top-left (np.int64(547), np.int64(106)), Bottom-right (np.int64(750), np.int64(364))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[1.]], Bounding box (normalized): [0.4905822  0.14431871 0.6300805  0.47696728]
# Bounding box (scaled): Top-left (np.int64(627), np.int64(103)), Bottom-right (np.int64(806), np.int64(343))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[1.]], Bounding box (normalized): [0.55739045 0.18727344 0.6886212  0.49472764]
# Bounding box (scaled): Top-left (np.int64(713), np.int64(134)), Bottom-right (np.int64(881), np.int64(356))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[1.]], Bounding box (normalized): [0.6030775  0.22472623 0.7482648  0.5160617 ]
# Bounding box (scaled): Top-left (np.int64(771), np.int64(161)), Bottom-right (np.int64(957), np.int64(371))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99999774]], Bounding box (normalized): [0.5949672  0.29751322 0.724707   0.5318908 ]
# Bounding box (scaled): Top-left (np.int64(761), np.int64(214)), Bottom-right (np.int64(927), np.int64(382))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99998474]], Bounding box (normalized): [0.54828054 0.32490885 0.6830603  0.52663386]
# Bounding box (scaled): Top-left (np.int64(701), np.int64(233)), Bottom-right (np.int64(874), np.int64(379))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9999841]], Bounding box (normalized): [0.53127265 0.35131758 0.6665214  0.54957885]
# Bounding box (scaled): Top-left (np.int64(680), np.int64(252)), Bottom-right (np.int64(853), np.int64(395))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99997014]], Bounding box (normalized): [0.5198128  0.34967348 0.64961207 0.53553605]
# Bounding box (scaled): Top-left (np.int64(665), np.int64(251)), Bottom-right (np.int64(831), np.int64(385))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9999333]], Bounding box (normalized): [0.53306437 0.3042709  0.651339   0.47309917]
# Bounding box (scaled): Top-left (np.int64(682), np.int64(219)), Bottom-right (np.int64(833), np.int64(340))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99973613]], Bounding box (normalized): [0.47894752 0.27052826 0.6080216  0.41806787]
# Bounding box (scaled): Top-left (np.int64(613), np.int64(194)), Bottom-right (np.int64(778), np.int64(301))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9977922]], Bounding box (normalized): [0.39040393 0.2257117  0.5101926  0.32894182]
# Bounding box (scaled): Top-left (np.int64(499), np.int64(162)), Bottom-right (np.int64(653), np.int64(236))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Confidence: [[0.9962847]], Bounding box (normalized): [0.37231115 0.20617816 0.49337807 0.30236197]
# Bounding box (scaled): Top-left (np.int64(476), np.int64(148)), Bottom-right (np.int64(631), np.int64(217))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9954992]], Bounding box (normalized): [0.34902528 0.2103662  0.47157413 0.30736887]
# Bounding box (scaled): Top-left (np.int64(446), np.int64(151)), Bottom-right (np.int64(603), np.int64(221))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.98777443]], Bounding box (normalized): [0.31119284 0.18942136 0.42043993 0.27554032]
# Bounding box (scaled): Top-left (np.int64(398), np.int64(136)), Bottom-right (np.int64(538), np.int64(198))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9887857]], Bounding box (normalized): [0.30942076 0.19386092 0.4156993  0.2773292 ]
# Bounding box (scaled): Top-left (np.int64(396), np.int64(139)), Bottom-right (np.int64(532), np.int64(199))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9917712]], Bounding box (normalized): [0.32091004 0.20720473 0.4279383  0.29503617]
# Bounding box (scaled): Top-left (np.int64(410), np.int64(149)), Bottom-right (np.int64(547), np.int64(212))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.98704636]], Bounding box (normalized): [0.30460447 0.20479535 0.40585247 0.28601652]
# Bounding box (scaled): Top-left (np.int64(389), np.int64(147)), Bottom-right (np.int64(519), np.int64(205))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.9881736]], Bounding box (normalized): [0.309599   0.21552071 0.41020742 0.29612666]
# Bounding box (scaled): Top-left (np.int64(396), np.int64(155)), Bottom-right (np.int64(525), np.int64(213))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9849699]], Bounding box (normalized): [0.28819308 0.20601785 0.39532956 0.2839237 ]
# Bounding box (scaled): Top-left (np.int64(368), np.int64(148)), Bottom-right (np.int64(506), np.int64(204))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9859795]], Bounding box (normalized): [0.29507476 0.21408954 0.40286297 0.29434043]
# Bounding box (scaled): Top-left (np.int64(377), np.int64(154)), Bottom-right (np.int64(515), np.int64(211))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.9923026]], Bounding box (normalized): [0.311423   0.22035892 0.42496273 0.31085053]
# Bounding box (scaled): Top-left (np.int64(398), np.int64(158)), Bottom-right (np.int64(543), np.int64(223))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9952518]], Bounding box (normalized): [0.32393157 0.20681007 0.4445593  0.30681637]
# Bounding box (scaled): Top-left (np.int64(414), np.int64(148)), Bottom-right (np.int64(569), np.int64(220))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.9963869]], Bounding box (normalized): [0.33681193 0.21478038 0.45955473 0.32135314]
# Bounding box (scaled): Top-left (np.int64(431), np.int64(154)), Bottom-right (np.int64(588), np.int64(231))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.99024993]], Bounding box (normalized): [0.30288213 0.17775214 0.4167506  0.27140722]
# Bounding box (scaled): Top-left (np.int64(387), np.int64(127)), Bottom-right (np.int64(533), np.int64(195))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.96705467]], Bounding box (normalized): [0.24765366 0.14134625 0.3467654  0.21788606]
# Bounding box (scaled): Top-left (np.int64(316), np.int64(101)), Bottom-right (np.int64(443), np.int64(156))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9631983]], Bounding box (normalized): [0.24369101 0.15206245 0.34070852 0.22747213]
# Bounding box (scaled): Top-left (np.int64(311), np.int64(109)), Bottom-right (np.int64(436), np.int64(163))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.86236805]], Bounding box (normalized): [0.17923342 0.12366509 0.25752446 0.1915959 ]
# Bounding box (scaled): Top-left (np.int64(229), np.int64(89)), Bottom-right (np.int64(329), np.int64(137))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.5974404]], Bounding box (normalized): [0.12943473 0.10856313 0.18758707 0.1723231 ]
# Bounding box (scaled): Top-left (np.int64(165), np.int64(78)), Bottom-right (np.int64(240), np.int64(124))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.5656843]], Bounding box (normalized): [0.13187632 0.12056398 0.1894794  0.17659092]
# Bounding box (scaled): Top-left (np.int64(168), np.int64(86)), Bottom-right (np.int64(242), np.int64(127))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.3195571]], Bounding box (normalized): [0.1107701  0.11795225 0.15805948 0.16659103]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.27909178]], Bounding box (normalized): [0.10693633 0.10963095 0.15399304 0.1554574 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.34654975]], Bounding box (normalized): [0.11361441 0.11089698 0.16345651 0.15924092]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.27265513]], Bounding box (normalized): [0.10268793 0.10584044 0.14559145 0.1532293 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.32826594]], Bounding box (normalized): [0.10863652 0.11877321 0.1497804  0.17168032]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.40233976]], Bounding box (normalized): [0.11631126 0.1184999  0.16216289 0.17261969]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.54902446]], Bounding box (normalized): [0.12989368 0.13371715 0.18027848 0.19512841]
# Bounding box (scaled): Top-left (np.int64(166), np.int64(96)), Bottom-right (np.int64(230), np.int64(140))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.40737346]], Bounding box (normalized): [0.11860144 0.1140727  0.16744602 0.16371885]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.47249645]], Bounding box (normalized): [0.12249763 0.12819147 0.17204526 0.1853848 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.3648507]], Bounding box (normalized): [0.11133387 0.12695329 0.15526037 0.18218143]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.31289887]], Bounding box (normalized): [0.10196959 0.11057212 0.14202537 0.15995479]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.10336177]], Bounding box (normalized): [0.0792841  0.08022404 0.11087552 0.11134373]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.08484297]], Bounding box (normalized): [0.08147392 0.08485488 0.11291652 0.11179876]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.16468331]], Bounding box (normalized): [0.09061581 0.09502321 0.12450873 0.1256689 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.39899236]], Bounding box (normalized): [0.11947793 0.12477366 0.16353576 0.16489653]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.16489647]], Bounding box (normalized): [0.09433829 0.09790849 0.12976657 0.12868932]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.41006702]], Bounding box (normalized): [0.1287806  0.17166485 0.17426606 0.22765954]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.94259405]], Bounding box (normalized): [0.2560711  0.34129807 0.3518422  0.45113295]
# Bounding box (scaled): Top-left (np.int64(327), np.int64(245)), Bottom-right (np.int64(450), np.int64(324))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9989838]], Bounding box (normalized): [0.33407992 0.3941255  0.47069648 0.6006526 ]
# Bounding box (scaled): Top-left (np.int64(427), np.int64(283)), Bottom-right (np.int64(602), np.int64(432))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9995964]], Bounding box (normalized): [0.34598875 0.35528263 0.47745994 0.57892215]
# Bounding box (scaled): Top-left (np.int64(442), np.int64(255)), Bottom-right (np.int64(611), np.int64(416))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99973464]], Bounding box (normalized): [0.34458214 0.37115586 0.4792785  0.6024547 ]
# Bounding box (scaled): Top-left (np.int64(441), np.int64(267)), Bottom-right (np.int64(613), np.int64(433))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9999117]], Bounding box (normalized): [0.3407545  0.39024234 0.48456925 0.65108675]
# Bounding box (scaled): Top-left (np.int64(436), np.int64(280)), Bottom-right (np.int64(620), np.int64(468))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.9999652]], Bounding box (normalized): [0.3856738  0.32859647 0.5183915  0.60274726]
# Bounding box (scaled): Top-left (np.int64(493), np.int64(236)), Bottom-right (np.int64(663), np.int64(433))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.9999902]], Bounding box (normalized): [0.43584213 0.24812739 0.55893487 0.52061343]
# Bounding box (scaled): Top-left (np.int64(557), np.int64(178)), Bottom-right (np.int64(715), np.int64(374))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9999758]], Bounding box (normalized): [0.4243589  0.21433216 0.54480344 0.46710187]
# Bounding box (scaled): Top-left (np.int64(543), np.int64(154)), Bottom-right (np.int64(697), np.int64(336))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99994856]], Bounding box (normalized): [0.3841199  0.28738007 0.5129101  0.53283155]
# Bounding box (scaled): Top-left (np.int64(491), np.int64(206)), Bottom-right (np.int64(656), np.int64(383))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99989796]], Bounding box (normalized): [0.32397723 0.32505065 0.45007    0.5663543 ]
# Bounding box (scaled): Top-left (np.int64(414), np.int64(234)), Bottom-right (np.int64(576), np.int64(407))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99867785]], Bounding box (normalized): [0.23380874 0.20497607 0.3610991  0.44606736]
# Bounding box (scaled): Top-left (np.int64(299), np.int64(147)), Bottom-right (np.int64(462), np.int64(321))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.98206335]], Bounding box (normalized): [0.14822072 0.16596678 0.25442675 0.376773  ]
# Bounding box (scaled): Top-left (np.int64(189), np.int64(119)), Bottom-right (np.int64(325), np.int64(271))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.00890985]], Bounding box (normalized): [0.03204281 0.02777693 0.04451609 0.05084061]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.00093437]], Bounding box (normalized): [0.01240216 0.01083298 0.01684216 0.0189575 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.00039596]], Bounding box (normalized): [0.00738014 0.00644113 0.00972582 0.0112887 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.00037252]], Bounding box (normalized): [0.00606951 0.0050836  0.00794802 0.00929612]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.00035594]], Bounding box (normalized): [0.00631371 0.00542751 0.00827437 0.00977554]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.00054607]], Bounding box (normalized): [0.00817247 0.00722051 0.01084957 0.01263125]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.00090084]], Bounding box (normalized): [0.01019506 0.00869848 0.01381919 0.01575397]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.00346608]], Bounding box (normalized): [0.02165808 0.01922933 0.02987083 0.03247006]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.01181482]], Bounding box (normalized): [0.03240264 0.02724834 0.04505515 0.05053079]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.13102262]], Bounding box (normalized): [0.05969906 0.06295782 0.08742552 0.12418577]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.5758263]], Bounding box (normalized): [0.08860309 0.10139156 0.13609244 0.21053265]
# Bounding box (scaled): Top-left (np.int64(113), np.int64(73)), Bottom-right (np.int64(174), np.int64(151))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.96447486]], Bounding box (normalized): [0.14072123 0.17152978 0.23613112 0.3691776 ]
# Bounding box (scaled): Top-left (np.int64(180), np.int64(123)), Bottom-right (np.int64(302), np.int64(265))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Confidence: [[0.99562204]], Bounding box (normalized): [0.17037523 0.20203482 0.2966145  0.4546804 ]
# Bounding box (scaled): Top-left (np.int64(218), np.int64(145)), Bottom-right (np.int64(379), np.int64(327))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.9991906]], Bounding box (normalized): [0.19174948 0.19645901 0.32573906 0.47953114]
# Bounding box (scaled): Top-left (np.int64(245), np.int64(141)), Bottom-right (np.int64(416), np.int64(345))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9995773]], Bounding box (normalized): [0.20433877 0.19167075 0.339496   0.4811293 ]
# Bounding box (scaled): Top-left (np.int64(261), np.int64(138)), Bottom-right (np.int64(434), np.int64(346))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9994567]], Bounding box (normalized): [0.20918198 0.19618516 0.3450748  0.4733555 ]
# Bounding box (scaled): Top-left (np.int64(267), np.int64(141)), Bottom-right (np.int64(441), np.int64(340))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.99948406]], Bounding box (normalized): [0.2122967  0.20296727 0.34912175 0.47834015]
# Bounding box (scaled): Top-left (np.int64(271), np.int64(146)), Bottom-right (np.int64(446), np.int64(344))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.99890435]], Bounding box (normalized): [0.21602635 0.2180893  0.35241675 0.47552854]
# Bounding box (scaled): Top-left (np.int64(276), np.int64(157)), Bottom-right (np.int64(451), np.int64(342))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99936]], Bounding box (normalized): [0.23428607 0.2281756  0.37141642 0.48455125]
# Bounding box (scaled): Top-left (np.int64(299), np.int64(164)), Bottom-right (np.int64(475), np.int64(348))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.9998061]], Bounding box (normalized): [0.2558529  0.23642813 0.39530534 0.50269073]
# Bounding box (scaled): Top-left (np.int64(327), np.int64(170)), Bottom-right (np.int64(505), np.int64(361))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9992828]], Bounding box (normalized): [0.2925065  0.27639905 0.419755   0.490078  ]
# Bounding box (scaled): Top-left (np.int64(374), np.int64(199)), Bottom-right (np.int64(537), np.int64(352))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9996662]], Bounding box (normalized): [0.3270523  0.29427087 0.4466377  0.5000983 ]
# Bounding box (scaled): Top-left (np.int64(418), np.int64(211)), Bottom-right (np.int64(571), np.int64(360))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99982876]], Bounding box (normalized): [0.35837308 0.31081992 0.4783462  0.51581764]
# Bounding box (scaled): Top-left (np.int64(458), np.int64(223)), Bottom-right (np.int64(612), np.int64(371))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99978966]], Bounding box (normalized): [0.37273213 0.30963865 0.49213147 0.5102729 ]
# Bounding box (scaled): Top-left (np.int64(477), np.int64(222)), Bottom-right (np.int64(629), np.int64(367))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9995452]], Bounding box (normalized): [0.3888693  0.3217707  0.5023432  0.50726485]
# Bounding box (scaled): Top-left (np.int64(497), np.int64(231)), Bottom-right (np.int64(642), np.int64(365))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99954885]], Bounding box (normalized): [0.39612758 0.3113306  0.5093037  0.50117826]
# Bounding box (scaled): Top-left (np.int64(507), np.int64(224)), Bottom-right (np.int64(651), np.int64(360))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.999333]], Bounding box (normalized): [0.3989886  0.31942344 0.5095334  0.50004154]
# Bounding box (scaled): Top-left (np.int64(510), np.int64(229)), Bottom-right (np.int64(652), np.int64(360))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99904335]], Bounding box (normalized): [0.40697205 0.31729904 0.51532197 0.488106  ]
# Bounding box (scaled): Top-left (np.int64(520), np.int64(228)), Bottom-right (np.int64(659), np.int64(351))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.9989351]], Bounding box (normalized): [0.40976155 0.31247744 0.5173574  0.48188117]
# Bounding box (scaled): Top-left (np.int64(524), np.int64(224)), Bottom-right (np.int64(662), np.int64(346))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9990241]], Bounding box (normalized): [0.41762364 0.30034888 0.52483517 0.47413015]
# Bounding box (scaled): Top-left (np.int64(534), np.int64(216)), Bottom-right (np.int64(671), np.int64(341))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9985436]], Bounding box (normalized): [0.41820163 0.31016558 0.52589583 0.47225234]
# Bounding box (scaled): Top-left (np.int64(535), np.int64(223)), Bottom-right (np.int64(673), np.int64(340))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.9987561]], Bounding box (normalized): [0.41921645 0.30860248 0.5264401  0.47464556]
# Bounding box (scaled): Top-left (np.int64(536), np.int64(222)), Bottom-right (np.int64(673), np.int64(341))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.99864393]], Bounding box (normalized): [0.42217392 0.3127833  0.52928853 0.47413552]
# Bounding box (scaled): Top-left (np.int64(540), np.int64(225)), Bottom-right (np.int64(677), np.int64(341))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.9990247]], Bounding box (normalized): [0.4302752  0.31831533 0.53939    0.4840867 ]
# Bounding box (scaled): Top-left (np.int64(550), np.int64(229)), Bottom-right (np.int64(690), np.int64(348))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.99858713]], Bounding box (normalized): [0.43219304 0.32069734 0.5442099  0.47431114]
# Bounding box (scaled): Top-left (np.int64(553), np.int64(230)), Bottom-right (np.int64(696), np.int64(341))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.9980883]], Bounding box (normalized): [0.4316447  0.32010615 0.5430716  0.4656751 ]
# Bounding box (scaled): Top-left (np.int64(552), np.int64(230)), Bottom-right (np.int64(695), np.int64(335))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99899065]], Bounding box (normalized): [0.44140404 0.31745583 0.55292284 0.47652796]
# Bounding box (scaled): Top-left (np.int64(564), np.int64(228)), Bottom-right (np.int64(707), np.int64(343))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.9989726]], Bounding box (normalized): [0.443702   0.3158385  0.5560621  0.47362044]
# Bounding box (scaled): Top-left (np.int64(567), np.int64(227)), Bottom-right (np.int64(711), np.int64(341))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Confidence: [[0.998419]], Bounding box (normalized): [0.43432194 0.31125614 0.5472056  0.46340764]
# Bounding box (scaled): Top-left (np.int64(555), np.int64(224)), Bottom-right (np.int64(700), np.int64(333))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9953789]], Bounding box (normalized): [0.40937003 0.30421877 0.5177375  0.43809593]
# Bounding box (scaled): Top-left (np.int64(523), np.int64(219)), Bottom-right (np.int64(662), np.int64(315))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Confidence: [[0.99914783]], Bounding box (normalized): [0.43405983 0.30499062 0.54534006 0.473721  ]
# Bounding box (scaled): Top-left (np.int64(555), np.int64(219)), Bottom-right (np.int64(698), np.int64(341))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9981485]], Bounding box (normalized): [0.4242192  0.3041799  0.53401756 0.45792967]
# Bounding box (scaled): Top-left (np.int64(543), np.int64(219)), Bottom-right (np.int64(683), np.int64(329))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.99830467]], Bounding box (normalized): [0.4249344  0.3050713  0.5345839  0.46145034]
# Bounding box (scaled): Top-left (np.int64(543), np.int64(219)), Bottom-right (np.int64(684), np.int64(332))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Confidence: [[0.99840766]], Bounding box (normalized): [0.42572278 0.29959485 0.5352811  0.45851278]
# Bounding box (scaled): Top-left (np.int64(544), np.int64(215)), Bottom-right (np.int64(685), np.int64(330))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99859095]], Bounding box (normalized): [0.42699486 0.2984799  0.53646576 0.46101373]
# Bounding box (scaled): Top-left (np.int64(546), np.int64(214)), Bottom-right (np.int64(686), np.int64(331))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.99877965]], Bounding box (normalized): [0.42873442 0.29937896 0.5379875  0.46479368]
# Bounding box (scaled): Top-left (np.int64(548), np.int64(215)), Bottom-right (np.int64(688), np.int64(334))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.9988912]], Bounding box (normalized): [0.42908987 0.29961506 0.5378619  0.46820086]
# Bounding box (scaled): Top-left (np.int64(549), np.int64(215)), Bottom-right (np.int64(688), np.int64(337))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99858767]], Bounding box (normalized): [0.426855   0.29577166 0.53611934 0.4600622 ]
# Bounding box (scaled): Top-left (np.int64(546), np.int64(212)), Bottom-right (np.int64(686), np.int64(331))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.9991557]], Bounding box (normalized): [0.4285402  0.29364166 0.5370411  0.46953467]
# Bounding box (scaled): Top-left (np.int64(548), np.int64(211)), Bottom-right (np.int64(687), np.int64(338))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Confidence: [[0.99965924]], Bounding box (normalized): [0.42935723 0.2894979  0.5393976  0.48576072]
# Bounding box (scaled): Top-left (np.int64(549), np.int64(208)), Bottom-right (np.int64(690), np.int64(349))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9997025]], Bounding box (normalized): [0.42894587 0.287613   0.5394694  0.48776984]
# Bounding box (scaled): Top-left (np.int64(549), np.int64(207)), Bottom-right (np.int64(690), np.int64(351))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Confidence: [[0.9997457]], Bounding box (normalized): [0.42792028 0.28592107 0.53936553 0.48949608]
# Bounding box (scaled): Top-left (np.int64(547), np.int64(205)), Bottom-right (np.int64(690), np.int64(352))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Confidence: [[0.99979967]], Bounding box (normalized): [0.42879575 0.28473452 0.541276   0.4923545 ]
# Bounding box (scaled): Top-left (np.int64(548), np.int64(205)), Bottom-right (np.int64(692), np.int64(354))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Confidence: [[0.99980044]], Bounding box (normalized): [0.42678285 0.29196888 0.53925604 0.49860466]
# Bounding box (scaled): Top-left (np.int64(546), np.int64(210)), Bottom-right (np.int64(690), np.int64(358))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.99971795]], Bounding box (normalized): [0.42676532 0.2966803  0.53725934 0.49627542]
# Bounding box (scaled): Top-left (np.int64(546), np.int64(213)), Bottom-right (np.int64(687), np.int64(357))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Confidence: [[0.99968135]], Bounding box (normalized): [0.42518702 0.3046982  0.53513104 0.49896902]
# Bounding box (scaled): Top-left (np.int64(544), np.int64(219)), Bottom-right (np.int64(684), np.int64(359))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Confidence: [[0.99967897]], Bounding box (normalized): [0.42471936 0.30297527 0.5347057  0.49699283]
# Bounding box (scaled): Top-left (np.int64(543), np.int64(218)), Bottom-right (np.int64(684), np.int64(357))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Confidence: [[0.9996955]], Bounding box (normalized): [0.42442712 0.30107123 0.5346496  0.49638063]
# Bounding box (scaled): Top-left (np.int64(543), np.int64(216)), Bottom-right (np.int64(684), np.int64(357))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Confidence: [[0.9996111]], Bounding box (normalized): [0.42328656 0.3037357  0.53259486 0.49379843]
# Bounding box (scaled): Top-left (np.int64(541), np.int64(218)), Bottom-right (np.int64(681), np.int64(355))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Confidence: [[0.99963814]], Bounding box (normalized): [0.4235645  0.30089936 0.5334442  0.49442628]
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Confidence: [[0.99980867]], Bounding box (normalized): [0.29699636 0.21337341 0.4171238  0.4626284 ]
# Bounding box (scaled): Top-left (np.int64(380), np.int64(153)), Bottom-right (np.int64(533), np.int64(333))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# Confidence: [[0.999724]], Bounding box (normalized): [0.28698328 0.21091983 0.40966702 0.4583774 ]
# Bounding box (scaled): Top-left (np.int64(367), np.int64(151)), Bottom-right (np.int64(524), np.int64(330))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Confidence: [[0.9998926]], Bounding box (normalized): [0.3031527  0.22058222 0.4239753  0.4744653 ]
# Bounding box (scaled): Top-left (np.int64(388), np.int64(158)), Bottom-right (np.int64(542), np.int64(341))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Confidence: [[0.9999912]], Bounding box (normalized): [0.34238103 0.22571437 0.4543418  0.4892198 ]
# Bounding box (scaled): Top-left (np.int64(438), np.int64(162)), Bottom-right (np.int64(581), np.int64(352))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Confidence: [[0.9999986]], Bounding box (normalized): [0.33871534 0.19659573 0.47007775 0.49104857]
# Bounding box (scaled): Top-left (np.int64(433), np.int64(141)), Bottom-right (np.int64(601), np.int64(353))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Confidence: [[0.9999969]], Bounding box (normalized): [0.32235378 0.12965274 0.46555993 0.4050053 ]
# Bounding box (scaled): Top-left (np.int64(412), np.int64(93)), Bottom-right (np.int64(595), np.int64(291))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Confidence: [[0.9999333]], Bounding box (normalized): [0.29748613 0.09152601 0.41694853 0.3006501 ]
# Bounding box (scaled): Top-left (np.int64(380), np.int64(65)), Bottom-right (np.int64(533), np.int64(216))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Confidence: [[0.9999068]], Bounding box (normalized): [0.2778939  0.07425523 0.39698946 0.26128742]
# Bounding box (scaled): Top-left (np.int64(355), np.int64(53)), Bottom-right (np.int64(508), np.int64(188))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Confidence: [[0.9998908]], Bounding box (normalized): [0.26841494 0.06630892 0.39602858 0.23719968]
# Bounding box (scaled): Top-left (np.int64(343), np.int64(47)), Bottom-right (np.int64(506), np.int64(170))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Confidence: [[0.99964124]], Bounding box (normalized): [0.24567586 0.06406822 0.36610436 0.21942507]
# Bounding box (scaled): Top-left (np.int64(314), np.int64(46)), Bottom-right (np.int64(468), np.int64(157))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Confidence: [[0.99725026]], Bounding box (normalized): [0.19254518 0.05214266 0.29137048 0.17306088]
# Bounding box (scaled): Top-left (np.int64(246), np.int64(37)), Bottom-right (np.int64(372), np.int64(124))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# Confidence: [[0.9985872]], Bounding box (normalized): [0.22352745 0.05657572 0.33339077 0.19583377]
# Bounding box (scaled): Top-left (np.int64(286), np.int64(40)), Bottom-right (np.int64(426), np.int64(141))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Confidence: [[0.99990046]], Bounding box (normalized): [0.28664452 0.06629577 0.43831253 0.2470553 ]
# Bounding box (scaled): Top-left (np.int64(366), np.int64(47)), Bottom-right (np.int64(561), np.int64(177))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Confidence: [[0.9999955]], Bounding box (normalized): [0.35110366 0.08153465 0.532591   0.3170494 ]
# Bounding box (scaled): Top-left (np.int64(449), np.int64(58)), Bottom-right (np.int64(681), np.int64(228))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Confidence: [[0.99999785]], Bounding box (normalized): [0.37592897 0.08593723 0.55932325 0.33195078]
# Bounding box (scaled): Top-left (np.int64(481), np.int64(61)), Bottom-right (np.int64(715), np.int64(239))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Confidence: [[0.9999915]], Bounding box (normalized): [0.3435739  0.07699227 0.5160174  0.29783908]
# Bounding box (scaled): Top-left (np.int64(439), np.int64(55)), Bottom-right (np.int64(660), np.int64(214))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Confidence: [[0.9999982]], Bounding box (normalized): [0.37598625 0.07554822 0.5468187  0.3144676 ]
# Bounding box (scaled): Top-left (np.int64(481), np.int64(54)), Bottom-right (np.int64(699), np.int64(226))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Confidence: [[0.9999962]], Bounding box (normalized): [0.35353908 0.06983154 0.51935005 0.293622  ]
# Bounding box (scaled): Top-left (np.int64(452), np.int64(50)), Bottom-right (np.int64(664), np.int64(211))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Confidence: [[0.99999636]], Bounding box (normalized): [0.3482401  0.06647395 0.5131178  0.28612897]
# Bounding box (scaled): Top-left (np.int64(445), np.int64(47)), Bottom-right (np.int64(656), np.int64(206))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Confidence: [[0.9999901]], Bounding box (normalized): [0.32513043 0.06402568 0.48522565 0.26821002]
# Bounding box (scaled): Top-left (np.int64(416), np.int64(46)), Bottom-right (np.int64(621), np.int64(193))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Confidence: [[0.9999896]], Bounding box (normalized): [0.32700285 0.0652026  0.48616496 0.27092066]
# Bounding box (scaled): Top-left (np.int64(418), np.int64(46)), Bottom-right (np.int64(622), np.int64(195))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Confidence: [[0.9999777]], Bounding box (normalized): [0.31935146 0.06831083 0.474231   0.26927292]
# Bounding box (scaled): Top-left (np.int64(408), np.int64(49)), Bottom-right (np.int64(607), np.int64(193))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Confidence: [[0.9999356]], Bounding box (normalized): [0.30008858 0.0687398  0.44939855 0.25817743]
# Bounding box (scaled): Top-left (np.int64(384), np.int64(49)), Bottom-right (np.int64(575), np.int64(185))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Confidence: [[0.99996144]], Bounding box (normalized): [0.3223318  0.07740529 0.4812991  0.27912483]
# Bounding box (scaled): Top-left (np.int64(412), np.int64(55)), Bottom-right (np.int64(616), np.int64(200))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Confidence: [[0.99995774]], Bounding box (normalized): [0.32361525 0.0819232  0.4908207  0.28641176]
# Bounding box (scaled): Top-left (np.int64(414), np.int64(58)), Bottom-right (np.int64(628), np.int64(206))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Confidence: [[0.99993443]], Bounding box (normalized): [0.29636335 0.07474533 0.46601957 0.26714358]
# Bounding box (scaled): Top-left (np.int64(379), np.int64(53)), Bottom-right (np.int64(596), np.int64(192))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Confidence: [[0.9998381]], Bounding box (normalized): [0.27314645 0.06748309 0.43138647 0.23850098]
# Bounding box (scaled): Top-left (np.int64(349), np.int64(48)), Bottom-right (np.int64(552), np.int64(171))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Confidence: [[0.9995978]], Bounding box (normalized): [0.24807775 0.06016325 0.3924726  0.20833497]
# Bounding box (scaled): Top-left (np.int64(317), np.int64(43)), Bottom-right (np.int64(502), np.int64(150))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Confidence: [[0.9997467]], Bounding box (normalized): [0.25765616 0.06298506 0.41126183 0.21503837]
# Bounding box (scaled): Top-left (np.int64(329), np.int64(45)), Bottom-right (np.int64(526), np.int64(154))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Confidence: [[0.99956715]], Bounding box (normalized): [0.24528965 0.06030424 0.39086732 0.20308645]
# Bounding box (scaled): Top-left (np.int64(313), np.int64(43)), Bottom-right (np.int64(500), np.int64(146))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Confidence: [[0.9998542]], Bounding box (normalized): [0.27618545 0.06662239 0.43912107 0.22681475]
# Bounding box (scaled): Top-left (np.int64(353), np.int64(47)), Bottom-right (np.int64(562), np.int64(163))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Confidence: [[0.99983054]], Bounding box (normalized): [0.27034444 0.06448069 0.4310562  0.22070394]
# Bounding box (scaled): Top-left (np.int64(346), np.int64(46)), Bottom-right (np.int64(551), np.int64(158))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Confidence: [[0.99988776]], Bounding box (normalized): [0.28359115 0.06772969 0.45009023 0.2336179 ]
# Bounding box (scaled): Top-left (np.int64(362), np.int64(48)), Bottom-right (np.int64(576), np.int64(168))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Confidence: [[0.99993026]], Bounding box (normalized): [0.28897938 0.06885403 0.46205965 0.25065607]
# Bounding box (scaled): Top-left (np.int64(369), np.int64(49)), Bottom-right (np.int64(591), np.int64(180))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Confidence: [[0.99995494]], Bounding box (normalized): [0.30362517 0.07302983 0.48042858 0.26684758]
# Bounding box (scaled): Top-left (np.int64(388), np.int64(52)), Bottom-right (np.int64(614), np.int64(192))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Confidence: [[0.99998003]], Bounding box (normalized): [0.3250095  0.07963099 0.505149   0.292789  ]
# Bounding box (scaled): Top-left (np.int64(416), np.int64(57)), Bottom-right (np.int64(646), np.int64(210))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Confidence: [[0.9999835]], Bounding box (normalized): [0.33652934 0.08495029 0.5153873  0.306253  ]
# Bounding box (scaled): Top-left (np.int64(430), np.int64(61)), Bottom-right (np.int64(659), np.int64(220))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Confidence: [[0.99996]], Bounding box (normalized): [0.3067153  0.07582164 0.4806947  0.27708265]
# Bounding box (scaled): Top-left (np.int64(392), np.int64(54)), Bottom-right (np.int64(615), np.int64(199))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Confidence: [[0.9999637]], Bounding box (normalized): [0.30993724 0.07804937 0.48467863 0.2830541 ]
# Bounding box (scaled): Top-left (np.int64(396), np.int64(56)), Bottom-right (np.int64(620), np.int64(203))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Confidence: [[0.9998959]], Bounding box (normalized): [0.28069267 0.07027017 0.44489753 0.2530183 ]
# Bounding box (scaled): Top-left (np.int64(359), np.int64(50)), Bottom-right (np.int64(569), np.int64(182))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Confidence: [[0.999911]], Bounding box (normalized): [0.29154518 0.07143962 0.45688516 0.25639588]
# Bounding box (scaled): Top-left (np.int64(373), np.int64(51)), Bottom-right (np.int64(584), np.int64(184))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Confidence: [[0.9994827]], Bounding box (normalized): [0.2328175  0.05597807 0.37378386 0.19345146]
# Bounding box (scaled): Top-left (np.int64(298), np.int64(40)), Bottom-right (np.int64(478), np.int64(139))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Confidence: [[0.99948746]], Bounding box (normalized): [0.23534265 0.05790131 0.37861744 0.19381781]
# Bounding box (scaled): Top-left (np.int64(301), np.int64(41)), Bottom-right (np.int64(484), np.int64(139))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Confidence: [[0.9987238]], Bounding box (normalized): [0.21051043 0.05296217 0.34422928 0.16697733]
# Bounding box (scaled): Top-left (np.int64(269), np.int64(38)), Bottom-right (np.int64(440), np.int64(120))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Confidence: [[0.9993895]], Bounding box (normalized): [0.23449965 0.05784222 0.38147214 0.18300842]
# Bounding box (scaled): Top-left (np.int64(300), np.int64(41)), Bottom-right (np.int64(488), np.int64(131))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# Confidence: [[0.99761176]], Bounding box (normalized): [0.19436987 0.04952776 0.32169753 0.15000437]
# Bounding box (scaled): Top-left (np.int64(248), np.int64(35)), Bottom-right (np.int64(411), np.int64(108))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Confidence: [[0.9981837]], Bounding box (normalized): [0.19638267 0.04923583 0.32979906 0.1490094 ]
# Bounding box (scaled): Top-left (np.int64(251), np.int64(35)), Bottom-right (np.int64(422), np.int64(107))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Confidence: [[0.9981038]], Bounding box (normalized): [0.19670235 0.04982817 0.3294764  0.14990519]
# Bounding box (scaled): Top-left (np.int64(251), np.int64(35)), Bottom-right (np.int64(421), np.int64(107))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Confidence: [[0.99828845]], Bounding box (normalized): [0.20607777 0.05268405 0.341115   0.15704568]
# Bounding box (scaled): Top-left (np.int64(263), np.int64(37)), Bottom-right (np.int64(436), np.int64(113))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Confidence: [[0.99612993]], Bounding box (normalized): [0.17836544 0.04625652 0.30065984 0.13738136]
# Bounding box (scaled): Top-left (np.int64(228), np.int64(33)), Bottom-right (np.int64(384), np.int64(98))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Confidence: [[0.9962423]], Bounding box (normalized): [0.18045963 0.04639974 0.30299154 0.13830791]
# Bounding box (scaled): Top-left (np.int64(230), np.int64(33)), Bottom-right (np.int64(387), np.int64(99))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Confidence: [[0.9969012]], Bounding box (normalized): [0.18232313 0.04598223 0.30656123 0.13891423]
# Bounding box (scaled): Top-left (np.int64(233), np.int64(33)), Bottom-right (np.int64(392), np.int64(100))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Confidence: [[0.99783015]], Bounding box (normalized): [0.19486757 0.04901601 0.32528794 0.14804149]
# Bounding box (scaled): Top-left (np.int64(249), np.int64(35)), Bottom-right (np.int64(416), np.int64(106))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Confidence: [[0.9986472]], Bounding box (normalized): [0.21035779 0.05250173 0.34882396 0.15847759]
# Bounding box (scaled): Top-left (np.int64(269), np.int64(37)), Bottom-right (np.int64(446), np.int64(114))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Confidence: [[0.998752]], Bounding box (normalized): [0.2152972  0.05421115 0.35584027 0.16234985]
# Bounding box (scaled): Top-left (np.int64(275), np.int64(39)), Bottom-right (np.int64(455), np.int64(116))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Confidence: [[0.9992112]], Bounding box (normalized): [0.22496995 0.05510876 0.37284705 0.16784494]
# Bounding box (scaled): Top-left (np.int64(287), np.int64(39)), Bottom-right (np.int64(477), np.int64(120))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Confidence: [[0.99863964]], Bounding box (normalized): [0.20612843 0.05133677 0.34541675 0.15479274]
# Bounding box (scaled): Top-left (np.int64(263), np.int64(36)), Bottom-right (np.int64(442), np.int64(111))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Confidence: [[0.997951]], Bounding box (normalized): [0.19759186 0.05030059 0.3308511  0.14965416]
# Bounding box (scaled): Top-left (np.int64(252), np.int64(36)), Bottom-right (np.int64(423), np.int64(107))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Confidence: [[0.9934388]], Bounding box (normalized): [0.16568235 0.04366361 0.2799894  0.1274746 ]
# Bounding box (scaled): Top-left (np.int64(212), np.int64(31)), Bottom-right (np.int64(358), np.int64(91))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Confidence: [[0.9534012]], Bounding box (normalized): [0.11626244 0.03367732 0.19781409 0.09470333]
# Bounding box (scaled): Top-left (np.int64(148), np.int64(24)), Bottom-right (np.int64(253), np.int64(68))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Confidence: [[0.98283136]], Bounding box (normalized): [0.1439414  0.04062225 0.24305241 0.11453336]
# Bounding box (scaled): Top-left (np.int64(184), np.int64(29)), Bottom-right (np.int64(311), np.int64(82))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Confidence: [[0.9959694]], Bounding box (normalized): [0.18188953 0.04794474 0.30449337 0.13844016]
# Bounding box (scaled): Top-left (np.int64(232), np.int64(34)), Bottom-right (np.int64(389), np.int64(99))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Confidence: [[0.9973527]], Bounding box (normalized): [0.19694497 0.05167131 0.326039   0.14956945]
# Bounding box (scaled): Top-left (np.int64(252), np.int64(37)), Bottom-right (np.int64(417), np.int64(107))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Confidence: [[0.9939684]], Bounding box (normalized): [0.17312594 0.04664408 0.28941917 0.13372716]
# Bounding box (scaled): Top-left (np.int64(221), np.int64(33)), Bottom-right (np.int64(370), np.int64(96))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Confidence: [[0.9936939]], Bounding box (normalized): [0.16920811 0.04513041 0.28408483 0.13053972]
# Bounding box (scaled): Top-left (np.int64(216), np.int64(32)), Bottom-right (np.int64(363), np.int64(93))
